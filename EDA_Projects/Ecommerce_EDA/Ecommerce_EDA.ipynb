# %%
####Importing packages and importing dataset for exploratory data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('C:/Users/jeeva/OneDrive/Documents/Data cleaning project/Ecommerce_datacleaned.csv')

# %%
###Checking the histogram so that data distribution could be understood among the numerical values
print(df.hist(figsize=(10,5)))
# Out:
# [[<Axes: title={'center': 'InvoiceNo'}>
#   <Axes: title={'center': 'Quantity'}>]
#  [<Axes: title={'center': 'UnitPrice'}>
#   <Axes: title={'center': 'CustomerID'}>]]

# %%
####checking which country has the high impact on entries
df['Country'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
####Correlation analysis to undertstand the relationship between two variables
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
####Checking the highest order quantity
df['Quantity'].idxmax()
df.loc[529800]
# Out:
# InvoiceNo                           581483
# StockCode                            23843
# Description    Paper Craft , Little Birdie
# Quantity                             80995
# InvoiceDate            2011-12-09 09:15:00
# UnitPrice                             2.08
# CustomerID                         16446.0
# Country                     United Kingdom
# Name: 529800, dtype: object

# %%
####re-check of outliers after cleaning the dataset
sns.boxplot(x=df['UnitPrice'])
# Out:
# <Axes: xlabel='UnitPrice'>

# %%
df.to_csv('C:/Users/jeeva/OneDrive/Documents/Exploratory data analysis/Ecommerce_EDA.csv', index=False)
